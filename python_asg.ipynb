# %% [markdown]
# <a href="https://colab.research.google.com/github/Jaishreesrinivasan24/Python/blob/main/python_asg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_html('https://en.wikipedia.org/wiki/List_of_highest-grossing_Indian_films')

# %%
df[1]
# Out:
#     Rank                            Title        Worldwide gross  \
# 0      1                           Dangal        ₹2,023.81 crore
# 1      2      Baahubali 2: The Conclusion       ₹1,810.595 crore
# 2      3                              RRR        ₹1,387.26 crore
# 3      4                   KGF: Chapter 2     ₹1,200–1,250 crore
# 4      5                            Jawan        ₹1,148.32 crore
# 5      6                          Pathaan        ₹1,050.30 crore
# 6      7                Bajrangi Bhaijaan          ₹969.06 crore
# 7      8                 Secret Superstar           ₹905.7 crore
# 8      9                         Animal *          ₹757.76 crore
# 9     10                               PK  ₹750.595–769.89 crore
# 10    11                              2.0             ₹699 crore
# 11    12                          Gadar 2          ₹691.08 crore
# 12    13                              Leo          ₹620.50 crore
# ...

# %%
movies=df[1]

# %%
type(movies)
# Out:
# pandas.core.frame.DataFrame

# %%
type(movies['Worldwide gross'])
# Out:
# pandas.core.series.Series

# %%
movies[['Worldwide gross']].shape
# Out:
# (50, 1)

# %%
movies[['Title','Worldwide gross']]
# Out:
#                               Title        Worldwide gross
# 0                            Dangal        ₹2,023.81 crore
# 1       Baahubali 2: The Conclusion       ₹1,810.595 crore
# 2                               RRR        ₹1,387.26 crore
# 3                    KGF: Chapter 2     ₹1,200–1,250 crore
# 4                             Jawan        ₹1,148.32 crore
# 5                           Pathaan        ₹1,050.30 crore
# 6                 Bajrangi Bhaijaan          ₹969.06 crore
# 7                  Secret Superstar           ₹905.7 crore
# 8                          Animal *          ₹757.76 crore
# 9                                PK  ₹750.595–769.89 crore
# 10                              2.0             ₹699 crore
# 11                          Gadar 2          ₹691.08 crore
# 12                              Leo          ₹620.50 crore
# 13                           Sultan  ₹614.49–615.705 crore
# 14                           Jailer         ₹607–610 crore
# ...

# %%
movies['Worldwide gross']
# Out:
# 0           ₹2,023.81 crore
# 1          ₹1,810.595 crore
# 2           ₹1,387.26 crore
# 3        ₹1,200–1,250 crore
# 4           ₹1,148.32 crore
# 5           ₹1,050.30 crore
# 6             ₹969.06 crore
# 7              ₹905.7 crore
# 8             ₹757.76 crore
# 9     ₹750.595–769.89 crore
# 10               ₹699 crore
# 11            ₹691.08 crore
# 12            ₹620.50 crore
# 13    ₹614.49–615.705 crore
# 14           ₹607–610 crore
# 15           ₹600–650 crore
# 16            ₹586.85 crore
# 17            ₹571.98 crore
# 18            ₹565.10 crore
# 19            ₹556.74 crore
# 20            ₹475.50 crore
# 21           ₹450–500 crore
# 22            ₹465.42 crore
# 23            ₹456.89 crore
# 24           ₹435– 500crore
# 25           ₹419–439 crore
# 26     ₹418.80–430.77 crore
# 27            ₹400.19 crore
# 28    ₹397.079–400.61 crore
# 29    ₹395.924–424.54 crore
# 30        ₹393.30–450 crore
# 31            ₹379.02 crore
# 32    ₹372.231–376.85 crore
# ...

# %%
movies.dtypes
# Out:
# Rank                    int64
# Title                  object
# Worldwide gross        object
# Primary language(s)    object
# Year                    int64
# Reference(s)           object
# dtype: object

# %%
movies.columns
# Out:
# Index(['Rank', 'Title', 'Worldwide gross', 'Primary language(s)', 'Year',
#        'Reference(s)'],
#       dtype='object')

# %%
#how to load csv,excel

# %%
from sklearn.datasets import fetch_california_housing

# %%
ca_ho = fetch_california_housing()

# %%
ca_ho
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
ca_ho.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'feature_names', 'DESCR'])

# %%
ca_ho.DESCR
# Out:
# '.. _california_housing_dataset:\n\nCalifornia Housing dataset\n--------------------------\n\n**Data Set Characteristics:**\n\n    :Number of Instances: 20640\n\n    :Number of Attributes: 8 numeric, predictive attributes and the target\n\n    :Attribute Information:\n        - MedInc        median income in block group\n        - HouseAge      median house age in block group\n        - AveRooms      average number of rooms per household\n        - AveBedrms     average number of bedrooms per household\n        - Population    block group population\n        - AveOccup      average number of household members\n        - Latitude      block group latitude\n        - Longitude     block group longitude\n\n    :Missing Attribute Values: None\n\nThis dataset was obtained from the StatLib repository.\nhttps://www.dcc.fc.up.pt/~ltorgo/Regression/cal_housing.html\n\nThe target variable is the median house value for California districts,\nexpressed in hundreds of thousands of dollars ($100,0
# ...

# %%
df=pd.DataFrame(ca_ho.data,columns=ca_ho.feature_names)

# %%
df.describe()
# Out:
#              MedInc      HouseAge      AveRooms     AveBedrms    Population  \
# count  20640.000000  20640.000000  20640.000000  20640.000000  20640.000000
# mean       3.870671     28.639486      5.429000      1.096675   1425.476744
# std        1.899822     12.585558      2.474173      0.473911   1132.462122
# min        0.499900      1.000000      0.846154      0.333333      3.000000
# 25%        2.563400     18.000000      4.440716      1.006079    787.000000
# 50%        3.534800     29.000000      5.229129      1.048780   1166.000000
# 75%        4.743250     37.000000      6.052381      1.099526   1725.000000
# max       15.000100     52.000000    141.909091     34.066667  35682.000000
#
#            AveOccup      Latitude     Longitude
# count  20640.000000  20640.000000  20640.000000
# mean       3.070655     35.631861   -119.569704
# std       10.386050      2.135952      2.003532
# min        0.692308     32.540000   -124.350000
# ...

# %%
df.hist(bins=30, figsize=(20,15), grid=False)
plt.show()
